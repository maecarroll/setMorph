# %% [markdown]
# # Measuring & Classifying Exponence

# %% [markdown]
# **NOTES**:
# 1. Definitions are still a little ad-hoc but the intuition all works
# 2. Measures still need need to implemented

# %% [markdown]
# A typology of exponence derived in set-theoretic terms making use of setmorph tools

# %%
import pandas as pd
import setmorph as sm
import itertools

# %% [markdown]
# Data files:

# %%
zen_df = pd.read_csv("testdata/sample-zen-out.csv")
ngkolmpu_df = pd.read_csv("testdata/sample-ng-tense-out.csv")
nuer_df = pd.read_csv("testdata/sample-nuer-out.csv")
arabic_df = pd.read_csv("testdata/sample-ar-out.csv")
rus_df = pd.read_csv("testdata/sample-rus-out.csv")
fr_df = pd.read_csv("testdata/sample-fr-out.csv")
uniq_df = pd.read_csv("testdata/unique_test.csv")

# %% [markdown]
# ## Delta

# %% [markdown]
# Delta is some feature based description of the distribution of a formative, $a$. It is a complete statement describing the cells where $a$ occurs. The total set of deltas for a formative can be considered the maximal knowledge of a speaker about the meaning/distribution of that formative.

# %% [markdown]
# - let $a$ be some formative
# - let $x$ be some set of features
# - let $y$ be some cell in $\mathrm{dist}(a)$
# - let $z$ be some cell in $\mathrm{cell}(\lambda)$
#
# We can then define $\delta_a$ as
# - some set of feature-sets, $\{ x_1, x_2, ... x_n \}$, such that:
#
# $$
# \forall x, \exists y, z \ (x \subseteq y, z) \\
# \forall y, \exists x \ (y \supseteq x ) \\
# \forall z \supseteq x, \exists y \supseteq x \ (z = y)
# $$

# %% [markdown]
# ## Simple exponence

# %% [markdown]
# a formatve, $a$, is said to be a *simple exponent* iff:
#
# $$
# \exists |\delta_a| = 1 \\
# |x \in \delta_a| = 1
# $$

# %%
simpleout = sm.classify_simple(ngkolmpu_df)
pd.DataFrame(simpleout)
# Out:
# /home/matt/Documents/GitHub/setMorph/src/setmorph/setmorph.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['celllist'] = parse_cell(df2)
#       lexeme       tier  slot formative    simple?
# 0       HIDE  segmental     2         u         no
# 1       HIDE  segmental     2         i         no
# 2       HIDE  segmental     3        ro  invariant
# 3       HIDE  segmental     5         i        yes
# 4       HIDE  segmental     5         u        yes
# ..       ...        ...   ...       ...        ...
# 149  DISROBE  segmental     2         ɛ        yes
# 150  DISROBE  segmental     7        ᵑk        yes
# 151  DISROBE  segmental     4        ər         no
# 152  DISROBE  segmental     7         n        yes
# 153  DISROBE  segmental     0         s         no
#
# [154 rows x 5 columns]

# %% [markdown]
# ### Syncretism

# %% [markdown]
# A formative $a$ is considered to be an example of syncretism iff:
#
# $\neg\exists \delta_a : |\delta_a| = 1$

# %% [markdown]
# There does not exist a description of 'a', $\delta_a$, which has a cardinality of 1, i.e. one set of features.

# %%
dfsyn = sm.classify_syn(ngkolmpu_df)
pd.DataFrame(dfsyn)
# Out:
#       lexeme       tier  slot formative  \
# 0       HIDE  segmental     2         u
# 1       HIDE  segmental     2         i
# 2       HIDE  segmental     3        ro
# 3       HIDE  segmental     5         i
# 4       HIDE  segmental     5         u
# ..       ...        ...   ...       ...
# 149  DISROBE  segmental     2         ɛ
# 150  DISROBE  segmental     7        ᵑk
# 151  DISROBE  segmental     4        ər
# 152  DISROBE  segmental     7         n
# 153  DISROBE  segmental     0         s
#
#                               minimal description  # sets minimally required  \
# 0                       {(rct, dur), (ipfv, rmt)}                        2.0
# 1    {(rmt, dur), (rct, ipfv), (prs), (hod, dur)}                        4.0
# 2                                       invariant                        0.0
# 3                                    {(hod, dur)}                        NaN
# 4                                    {(rmt, dur)}                        NaN
# ..                                            ...                        ...
# 149                                       {(pfv)}                        NaN
# 150                                  {(rmt, pfv)}                        NaN
# 151                               {(ipfv), (dur)}                        2.0
# 152                                 {(rct, ipfv)}                        NaN
# 153       {(pfv), (ipfv, rmt), (rct, dur), (fut)}                        4.0
#
#      # of cells
# 0           2.0
# 1           4.0
# 2          11.0
# 3           NaN
# 4           NaN
# ..          ...
# 149         NaN
# 150         NaN
# 151         7.0
# 152         NaN
# 153         7.0
#
# [154 rows x 7 columns]

# %% [markdown]
# **Measurement**
#
# - Number of cells
# - Number of 'sets' in minimal description
#
# To be implemented:
# - Ratio of values over length of a dimension, i.e. 2 cases out of 12 total (harder to do given current implementation.

# %% [markdown]
# ### Cumulative exponence

# %% [markdown]
# A formative $a$ is considered an example of cumulative exponence iff:
#
# $\neg\exists \delta_a : \forall x \in \delta_a, |x| = 1$

# %% [markdown]
# There does not exists a $\delta_a$ such that for all sets of features in $\delta_a$ they have a cardinality of 1.

# %%
dfout = sm.classify_cumulation(ngkolmpu_df)
pd.DataFrame(dfout)
# Out:
# /home/matt/Documents/GitHub/setMorph/src/setmorph/setmorph.py:192: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['celllist'] = parse_cell(df2)
#       lexeme       tier  slot formative  \
# 0       HIDE  segmental     2         u
# 1       HIDE  segmental     2         i
# 2       HIDE  segmental     3        ro
# 3       HIDE  segmental     5         i
# 4       HIDE  segmental     5         u
# ..       ...        ...   ...       ...
# 149  DISROBE  segmental     2         ɛ
# 150  DISROBE  segmental     7        ᵑk
# 151  DISROBE  segmental     4        ər
# 152  DISROBE  segmental     7         n
# 153  DISROBE  segmental     0         s
#
#                           cumulative cells  longest cumulation  \
# 0                [(rct, dur), (ipfv, rmt)]                   2
# 1    [(rmt, dur), (rct, ipfv), (hod, dur)]                   2
# 2                                        0                   0
# 3                                        0                   0
# 4                                        0                   0
# ..                                     ...                 ...
# 149                                      0                   0
# 150                                      0                   0
# 151                                      0                   0
# 152                                      0                   0
# 153              [(ipfv, rmt), (rct, dur)]                   2
#
#      % cells cumulative  % dimensions cumulation
# 0            100.000000                    100.0
# 1             75.000000                    100.0
# 2              0.000000                      0.0
# 3              0.000000                      0.0
# 4              0.000000                      0.0
# ..                  ...                      ...
# 149            0.000000                      0.0
# 150            0.000000                      0.0
# 151            0.000000                      0.0
# 152            0.000000                      0.0
# 153           28.571429                    100.0
#
# [154 rows x 8 columns]

# %% [markdown]
# **Measurement**
#
# - Longest cumulation: how many feature values get cumulated at most
# - Longest cumulation / longest possible cumulation
# - % cells cumulative - percentage of cells in dist(a) which must be described using cumulation (based on minimal descrition currently)
# - % dimensions - length of longest cumulation / longest possible cumulation

# %% [markdown]
# ## Unique exponence

# %% [markdown]
# For a given value, v:
# There is only one formative for which its all its deltas must contain that value:
#
# $\exists!a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) $

# %% [markdown]
# alternatively:

# %% [markdown]
# $| \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | = 1$

# %% [markdown]
# There exists exactly one $a$ such that all the descriptions of $a$, there exists a set in that description that contains that value.

# %%
uniq = pd.DataFrame(sm.classify_unique(ngkolmpu_df))
uniq
# Out:
#       lexeme value  slot form
# 0       HIDE   prs     2    i
# 1      STALK   prs     1    y
# 2       TELL   hod     5    i
# 3      EJECT   prs     2    i
# 4      TOUCH   prs     2    i
# 5     FOLLOW   prs     2    i
# 6       STAB   prs     2    i
# 7  FINE_WORK   prs     1    y
# 8    DISROBE   prs     2    i

# %% [markdown]
# ### Verbose exponence

# %% [markdown]
# For a given value, v and some word $\omega$:

# %% [markdown]
# $$| \{  a \in \mathrm{wordform}(\omega): \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1$ \\
# $$

# %%
ve_ngkolmpu = sm.classify_VE(ngkolmpu_df)
pd.DataFrame(ve_ngkolmpu)
# Out:
#       lexeme value                              word  \
# 0       HIDE   hod                (hod.dur, i r o i)
# 1       HIDE   rct                (rct.dur, s u r o)
# 2       HIDE   rct             (rct.pfv, s ə r o ⁿt)
# 3       HIDE   rct           (rct.ipfv, i r o j ə n)
# 4       HIDE  ipfv          (rmt.ipfv, s u r o r ⁿt)
# ..       ...   ...                               ...
# 184  DISROBE   fut        (fut.pfv, s ə r ɛ s i p ɛ)
# 185  DISROBE   fut     (fut.dur, s ə r s i p ə r ⁿt)
# 186  DISROBE   rmt         (rmt.pfv, s ɛ s i p ɛ ᵑk)
# 187  DISROBE   rmt          (rmt.dur, i s i p ə r u)
# 188  DISROBE   rmt  (rmt.ipfv, s u s i p ə r ə r ⁿt)
#
#                                             formatives  # formatives
# 0               [(segmental, 2, i), (segmental, 5, i)]             2
# 1               [(segmental, 2, u), (segmental, 0, s)]             2
# 2              [(segmental, 5, ⁿt), (segmental, 0, s)]             2
# 3             [(segmental, 2, i), (segmental, 5, jən)]             2
# 4    [(segmental, 2, u), (segmental, 4, r), (segmen...             4
# ..                                                 ...           ...
# 184            [(segmental, 1, ər), (segmental, 0, s)]             2
# 185  [(segmental, 7, ⁿt), (segmental, 1, ər), (segm...             3
# 186            [(segmental, 7, ᵑk), (segmental, 0, s)]             2
# 187             [(segmental, 7, u), (segmental, 2, i)]             2
# 188  [(segmental, 2, u), (segmental, 6, r), (segmen...             4
#
# [189 rows x 5 columns]

# %% [markdown]
# **Measurement:**
#
# - '# of formatives': number of formatives expressing that valuein a given word
#
# To be implemented / further processing of the above dataframe:
# - We could also do an average of formatives expressing a given value
# - Number of cells where it is expressed verbose

# %% [markdown]
# ### Allomorphy

# %% [markdown]
# This one is most problematic - still needs tweaking how it fits into the typology, how to measure and define.

# %% [markdown]
# There is more than one formative which expresses a given value and these don't co-occur.

# %% [markdown]
# For a given value, $v$, we see allomorphy if:
#
# $$
# \exists a, b : \forall \delta_a, \delta_b, \exists x \in \delta \ ( v \in x $ )\\
# \{\Sigma \in \mathrm{dist}(a)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(b)| v \in \Sigma\} $$

# %% [markdown]
# Alternatively:

# %% [markdown]
# $$
# | \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1 \\
# \exists a_i,a_j : \{\Sigma \in \mathrm{dist}(a_i)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(a_j)| v \in \Sigma\}
# $$

# %% [markdown]
# 1. The number of formatives which have $v$ in all their deltas is more than one
# 2. There exist at least two formative which do not only occur in the same set of cells which contain $v$

# %%
allo = sm.classify_allomorphy(ngkolmpu_df)
pd.DataFrame(allo)
# Out:
#      lexeme value  # allomorphs  % of allomorphs to cells containing v  \
# 0      HIDE   rct             5                             166.666667
# 1      HIDE  ipfv             5                             250.000000
# 2      HIDE   dur             6                             120.000000
# 3      HIDE   pfv             3                              75.000000
# 4      HIDE   fut             2                             100.000000
# ..      ...   ...           ...                                    ...
# 58  DISROBE  ipfv             6                             300.000000
# 59  DISROBE   dur             7                             140.000000
# 60  DISROBE   pfv             3                              75.000000
# 61  DISROBE   fut             2                             100.000000
# 62  DISROBE   rmt             6                             200.000000
#
#                                                 forms
# 0   [[(segmental, 2, u)], [(segmental, 2, i)], [(s...
# 1   [[(segmental, 2, u)], [(segmental, 2, i)], [(s...
# 2   [[(segmental, 2, u)], [(segmental, 2, i)], [(s...
# 3   [[(segmental, 2, ə), (segmental, 0, s)], [(seg...
# 4   [[(segmental, 2, ə), (segmental, 1, ər), (segm...
# ..                                                ...
# 58  [[(segmental, 5, ə), (segmental, 4, ər)], [(se...
# 59  [[(segmental, 4, ər)], [(segmental, 7, u)], [(...
# 60  [[(segmental, 6, ɛ), (segmental, 2, ɛ), (segme...
# 61  [[(segmental, 1, ər), (segmental, 0, s)], [(se...
# 62  [[(segmental, 7, u)], [(segmental, 2, u)], [(s...
#
# [63 rows x 5 columns]

# %% [markdown]
# **Measurement**
#
# - '# of allomorphs'
# - '% of allowmorphs to cells containing v' - this can be greater than 100% under current implementation.

# %% [markdown]
# Examples:
#
# | (a) SG|  | (b) SG |   | (c) SG |   | (d) SG |
# |---|      |---|        |---|        |---|
# |x|        | x  |       | x  |       | x  |
# |y|        | xy |       | x  |       | x  |
# |z|        |  y |       | xy |       | yz |

# %% [markdown]
# The current implementation treats the analysis of 'allomorphy of singular' as:
#
# - (a): x, y, z
# - (b): x, y
# - (c): x, y
# - (d): x, yz
#
# Another implementation might consider the following:
#
# - (a): x, y, z
# - (b): x, xy, y
# - (c): x, xy
# - (d): x, yz

# %% [markdown]
# ## Higher-order exceptionality

# %% [markdown]
# See Carroll (2022)
