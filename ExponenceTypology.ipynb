# %% [markdown]
# # Measuring & Classifying Exponence

# %% [markdown]
# **NOTES**:
# 1. Definitions are still a little ad-hoc but the intuition all works
# 2. Measures still need need to implemented

# %% [markdown]
# A typology of exponence derived in set-theoretic terms making use of setmorph tools

# %%
import setmorph as sm

# %% [markdown]
# Data files:

# %%
zen_df = sm.read_paradigms("src/setmorph/testdata/sample-zen-out.csv")
ngkolmpu_df = sm.read_paradigms("src/setmorph/testdata/sample-ng-tense-out.csv")
nuer_df = sm.read_paradigms("src/setmorph/testdata/sample-nuer-out.csv")
arabic_df = sm.read_paradigms("src/setmorph/testdata/sample-ar-out.csv")
rus_df = sm.read_paradigms("src/setmorph/testdata/sample-rus-out.csv")
fr_df = sm.read_paradigms("src/setmorph/testdata/sample-fr-out.csv")
uniq_df = sm.read_paradigms("src/setmorph/testdata/unique_test.csv")

# %%
fr_features = sm.read_features("src/setmorph/testdata/fr_features.csv")
ng_features = sm.read_features("src/setmorph/testdata/ng_features.csv")
ar_features = sm.read_features("src/setmorph/testdata/ar_features.csv")
nuer_features = sm.read_features("src/setmorph/testdata/nuer_features.csv")
rus_features = sm.read_features("src/setmorph/testdata/rus_features.csv")
zen_features = sm.read_features("src/setmorph/testdata/zen_features.csv")
# Out:
# WARNING:root:The feature `mood` has a single value `ind`. No exponents of `ind` will be possible.
# WARNING:root:The feature `tense` has a single value `prs`. No exponents of `prs` will be possible.
# WARNING:root:The feature `voice` has a single value `act`. No exponents of `act` will be possible.
# WARNING:root:The feature `case` has a single value `nom`. No exponents of `nom` will be possible.

# %% [markdown]
# ## Delta

# %% [markdown]
# Delta is some feature based description of the distribution of a formative, $a$. It is a complete statement describing the cells where $a$ occurs. The total set of deltas for a formative can be considered the maximal knowledge of a speaker about the meaning/distribution of that formative.

# %% [markdown]
# - let $a$ be some formative
# - let $x$ be some set of features
# - let $y$ be some cell in $\mathrm{dist}(a)$
# - let $z$ be some cell in $\mathrm{cell}(\lambda)$
#
# We can then define $\delta_a$ as
# - some set of feature-sets, $\{ x_1, x_2, ... x_n \}$, such that:
#
# $$
# \forall x \in \delta_a, \exists y, z \ (x \subseteq y, z) \\
# \forall y, \exists x  \in \delta_a \ (y \supseteq x ) \\
# \forall z \supseteq x, \exists y \supseteq x \ (z = y)
# $$
#
# Which means:
# 1. All sets of features in $\delta_a$ are subsets of at least a cell which is in the distribution of $a$.
# 2. All cells in the distribution of $a$ are represented by a subset $x$ in $\delta_a$
# 3. All cells that are supersets of an $x$ in $\delta_a$ are in the distribution of $a$

# %% [markdown]
# ## Simple exponence

# %% [markdown]
# a formatve, $a$, is said to be a *simple exponent* iff:
#
# $$
# \exists |\delta_a| = 1 \\
# |x \in \delta_a| = 1
# $$

# %%
fr_df
# Out:
#      lexeme      cell    form       tier  slot formative     celllist
# 0     aller   prs.1sg     v E  segmental     0         v   (prs, 1sg)
# 1     aller   prs.1sg     v E  segmental     1         E   (prs, 1sg)
# 2     aller   prs.2sg     v a  segmental     0         v   (prs, 2sg)
# 3     aller   prs.2sg     v a  segmental     1         a   (prs, 2sg)
# 4     aller   prs.3sg     v a  segmental     0         v   (3sg, prs)
# ...     ...       ...     ...        ...   ...       ...          ...
# 1320  touer       inf   t w E  segmental     2         w        (inf)
# 1321  touer       inf   t w E  segmental     3         E        (inf)
# 1322  touer  prs.ptcp  t w ɑ̃  segmental     0         t  (ptcp, prs)
# 1323  touer  prs.ptcp  t w ɑ̃  segmental     2         w  (ptcp, prs)
# 1324  touer  prs.ptcp  t w ɑ̃  segmental     4        ɑ̃  (ptcp, prs)
#
# [1325 rows x 7 columns]

# %% [markdown]
# We start by computing all exponents relations once and for all:

# %%
exponents = sm.find_exponents(fr_df, fr_features)
exponents
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(1pl, prs), (pst), (prs, 2pl)}          10
# 1                                              {(fut)}           6
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (inf), (pst, 3pl), (prs, 2pl), (1...           7
# 4               {(pst, 1pl), (3sg), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a
# 0    {(1pl, prs), (pst, 1pl), (inf), (pst, 3pl), (p...
# 1    {(fut, 1sg), (fut, 2pl), (3sg, fut), (1pl, fut...
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}
# 3    {(fut, 1sg), (fut, 2pl), (inf), (pst, 3pl), (p...
# 4    {(pst, 1pl), (3sg, fut), (pst, 2pl), (pst, 2sg...
# ..                                                 ...
# 240                                       {(pst, 1pl)}
# 241                                       {(pst, 2pl)}
# 242                                      {(ptcp, prs)}
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}
# 244                                       {(pst, 3pl)}
#
# [245 rows x 7 columns]

# %%
sm.classify_simple(exponents)
exponents
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(1pl, prs), (pst), (prs, 2pl)}          10
# 1                                              {(fut)}           6
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (inf), (pst, 3pl), (prs, 2pl), (1...           7
# 4               {(pst, 1pl), (3sg), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a simple
# 0    {(1pl, prs), (pst, 1pl), (inf), (pst, 3pl), (p...  False
# 1    {(fut, 1sg), (fut, 2pl), (3sg, fut), (1pl, fut...   True
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}  False
# 3    {(fut, 1sg), (fut, 2pl), (inf), (pst, 3pl), (p...  False
# 4    {(pst, 1pl), (3sg, fut), (pst, 2pl), (pst, 2sg...  False
# ..                                                 ...    ...
# 240                                       {(pst, 1pl)}   True
# 241                                       {(pst, 2pl)}   True
# 242                                      {(ptcp, prs)}   True
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}  False
# 244                                       {(pst, 3pl)}   True
#
# [245 rows x 8 columns]

# %% [markdown]
# ### Syncretism

# %% [markdown]
# A formative $a$ is considered to be an example of syncretism iff:
#
# $\neg\exists \delta_a : |\delta_a| = 1$

# %% [markdown]
# There does not exist a description of 'a', $\delta_a$, which has a cardinality of 1, i.e. one set of features.

# %%
sm.classify_syn(exponents)
exponents
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(1pl, prs), (pst), (prs, 2pl)}          10
# 1                                              {(fut)}           6
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (inf), (pst, 3pl), (prs, 2pl), (1...           7
# 4               {(pst, 1pl), (3sg), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a simple  \
# 0    {(1pl, prs), (pst, 1pl), (inf), (pst, 3pl), (p...  False
# 1    {(fut, 1sg), (fut, 2pl), (3sg, fut), (1pl, fut...   True
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}  False
# 3    {(fut, 1sg), (fut, 2pl), (inf), (pst, 3pl), (p...  False
# 4    {(pst, 1pl), (3sg, fut), (pst, 2pl), (pst, 2sg...  False
# ..                                                 ...    ...
# 240                                       {(pst, 1pl)}   True
# 241                                       {(pst, 2pl)}   True
# 242                                      {(ptcp, prs)}   True
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}  False
# 244                                       {(pst, 3pl)}   True
#
#      # sets minimally required
# 0                            3
# 1                            1
# 2                            4
# 3                            5
# 4                            4
# ..                         ...
# 240                          1
# 241                          1
# 242                          1
# 243                          3
# 244                          1
#
# [245 rows x 9 columns]

# %% [markdown]
# **Measurement**
#
# - Number of cells
# - Number of 'sets' in minimal description
#
# To be implemented:
# - TODO: Ratio of values over length of a dimension, i.e. 2 cases out of 12 total (harder to do given current implementation.

# %% [markdown]
# ### Cumulative exponence

# %% [markdown]
# A formative $a$ is considered an example of cumulative exponence iff:
#
# $\neg\exists \delta_a : \forall x \in \delta_a, |x| = 1$

# %% [markdown]
# There does not exists a $\delta_a$ such that for all sets of features in $\delta_a$ they have a cardinality of 1.

# %%
max_dimensions = fr_df["celllist"].fillna("").apply(len).max()
sm.classify_cumulation(exponents, max_dimensions)
exponents
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(1pl, prs), (pst), (prs, 2pl)}          10
# 1                                              {(fut)}           6
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (inf), (pst, 3pl), (prs, 2pl), (1...           7
# 4               {(pst, 1pl), (3sg), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a simple  \
# 0    {(1pl, prs), (pst, 1pl), (inf), (pst, 3pl), (p...  False
# 1    {(fut, 1sg), (fut, 2pl), (3sg, fut), (1pl, fut...   True
# 2     {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}  False
# 3    {(fut, 1sg), (fut, 2pl), (inf), (pst, 3pl), (p...  False
# 4    {(pst, 1pl), (3sg, fut), (pst, 2pl), (pst, 2sg...  False
# ..                                                 ...    ...
# 240                                       {(pst, 1pl)}   True
# 241                                       {(pst, 2pl)}   True
# 242                                      {(ptcp, prs)}   True
# 243               {(1pl, fut), (1pl, prs), (3pl, fut)}  False
# 244                                       {(pst, 3pl)}   True
#
#      # sets minimally required  \
# 0                            3
# 1                            1
# 2                            4
# 3                            5
# 4                            4
# ..                         ...
# 240                          1
# 241                          1
# 242                          1
# 243                          3
# 244                          1
#
#                                      cumulative cells  longest cumulation  \
# 0                            {(1pl, prs), (prs, 2pl)}                   2
# 1                                                  {}                   0
# 2    {(prs, 2sg), (3sg, prs), (prs, 1sg), (3pl, prs)}                   2
# 3                {(fut, 2pl), (prs, 2pl), (pst, 3pl)}                   2
# 4                            {(pst, 1pl), (pst, 2pl)}                   2
# ..                                                ...                 ...
# 240                                      {(pst, 1pl)}                   2
# 241                                      {(pst, 2pl)}                   2
# 242                                                {}                   0
# 243              {(1pl, fut), (1pl, prs), (3pl, fut)}                   2
# 244                                      {(pst, 3pl)}                   2
#
#      % cells cumulative  % dimensions cumulation
# 0             20.000000                    100.0
# 1              0.000000                      0.0
# 2            100.000000                    100.0
# 3             42.857143                    100.0
# 4             25.000000                    100.0
# ..                  ...                      ...
# 240          100.000000                    100.0
# 241          100.000000                    100.0
# 242            0.000000                      0.0
# 243          100.000000                    100.0
# 244          100.000000                    100.0
#
# [245 rows x 13 columns]

# %% [markdown]
# **Measurement**
#
# - Longest cumulation: how many feature values get cumulated at most
# - Longest cumulation / longest possible cumulation
# - % cells cumulative - percentage of cells in dist(a) which must be described using cumulation (based on minimal descrition currently)
# - % dimensions - length of longest cumulation / longest possible cumulation

# %% [markdown]
# ## Values table

# %% [markdown]
# We reorganize the information so that each row represents one exponential value in a single word, with a list of its formatives.

# %%
values_words = sm.values_per_word(fr_df, exponents)

# %%
values_words
# Out:
#     lexeme value     form     cell  \
# 0    aller   1pl   i ʁ ɔ̃  fut.1pl
# 1    aller   fut   i ʁ ɔ̃  fut.1pl
# 2    aller   1sg    i ʁ E  fut.1sg
# 3    aller   fut    i ʁ E  fut.1sg
# 4    aller   2pl    i ʁ E  fut.2pl
# ..     ...   ...      ...      ...
# 696  touer   pst    t w a  pst.2sg
# 697  touer   3pl  t w E ʁ  pst.3pl
# 698  touer   pst  t w E ʁ  pst.3pl
# 699  touer   3sg    t w a  pst.3sg
# 700  touer   pst    t w a  pst.3sg
#
#                                              formative
# 0                                ((segmental, 2, ɔ̃),)
# 1             ((segmental, 0, iʁ), (segmental, 2, ɔ̃))
# 2                                 ((segmental, 1, E),)
# 3                                ((segmental, 0, iʁ),)
# 4                                 ((segmental, 1, E),)
# ..                                                 ...
# 696             ((segmental, 2, w), (segmental, 3, a))
# 697             ((segmental, 3, E), (segmental, 4, ʁ))
# 698  ((segmental, 2, w), (segmental, 3, E), (segmen...
# 699                               ((segmental, 3, a),)
# 700             ((segmental, 2, w), (segmental, 3, a))
#
# [701 rows x 5 columns]

# %% [markdown]
# We also need a table where rows represent values (across words) and also give lists of formatives

# %%
values = sm.values_table(values_words)
values
# Out:
#     lexeme value                                          formative  \
# 0    aller   1pl  {(segmental, 1, a), (segmental, 2, ɔ̃), (segme...
# 1    aller   1sg             {(segmental, 1, E), (segmental, 0, v)}
# 2    aller   2pl  {(segmental, 1, E), (segmental, 1, a), (segmen...
# 3    aller   2sg             {(segmental, 1, a), (segmental, 0, v)}
# 4    aller   3pl  {(segmental, 1, E), (segmental, 2, ʁ), (segmen...
# ..     ...   ...                                                ...
# 237  touer   fut  {(segmental, 4, ɔ̃), (segmental, 3, a), (segme...
# 238  touer   inf                                {(segmental, 3, E)}
# 239  touer   prs  {(segmental, 1, u), (segmental, 3, E), (segmen...
# 240  touer   pst  {(segmental, 4, ʁ), (segmental, 2, w), (segmen...
# 241  touer  ptcp                               {(segmental, 4, ɑ̃)}
#
#                                     formatives_by_word
# 0    {((segmental, 2, ɔ̃),), ((segmental, 1, a), (s...
# 1    {((segmental, 1, E),), ((segmental, 0, v), (se...
# 2    {((segmental, 0, al), (segmental, 1, E)), ((se...
# 3    {((segmental, 0, v), (segmental, 1, a)), ((seg...
# 4    {((segmental, 0, v), (segmental, 2, ɔ̃)), ((se...
# ..                                                 ...
# 237  {((segmental, 1, u), (segmental, 2, ʁ), (segme...
# 238                             {((segmental, 3, E),)}
# 239  {((segmental, 2, w), (segmental, 4, ɔ̃)), ((se...
# 240  {((segmental, 2, w), (segmental, 3, a), (segme...
# 241                            {((segmental, 4, ɑ̃),)}
#
# [242 rows x 4 columns]

# %% [markdown]
# ## Unique exponence

# %% [markdown]
# For a given value, v:
# There is only one formative for which its all its deltas must contain that value:
#
# $\exists!a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) $

# %% [markdown]
# alternatively:

# %% [markdown]
# $| \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | = 1$

# %% [markdown]
# There exists exactly one $a$ such that all the descriptions of $a$, there exists a set in that description that contains that value.
#
# In other words, given a lexeme and a value, only a single exponent expresses it.

# %%
sm.count_formatives(values)
values[values["# formatives"] == 1]
# Out:
#           lexeme value             formative       formatives_by_word  \
# 7          aller   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 10         aller  ptcp  {(segmental, 2, ɑ̃)}  {((segmental, 2, ɑ̃),)}
# 34        croire   1sg   {(segmental, 4, E)}   {((segmental, 4, E),)}
# 36        croire   2sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 38        croire   3sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 45         cuire   1sg   {(segmental, 3, E)}   {((segmental, 3, E),)}
# 47         cuire   2sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 49         cuire   3sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 51         cuire   inf   {(segmental, 1, ʁ)}   {((segmental, 1, ʁ),)}
# 56     engloutir   1sg   {(segmental, 2, E)}   {((segmental, 2, E),)}
# 58     engloutir   2sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 60     engloutir   3sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 62     engloutir   inf   {(segmental, 1, ʁ)}   {((segmental, 1, ʁ),)}
# 67         finir   1sg   {(segmental, 2, E)}   {((segmental, 2, E),)}
# 69         finir   2sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 71         finir   3sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 73         finir   inf   {(segmental, 1, ʁ)}   {((segmental, 1, ʁ),)}
# 78          haïr   1sg   {(segmental, 2, E)}   {((segmental, 2, E),)}
# 80          haïr   2sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 82          haïr   3sg   {(segmental, 2, a)}   {((segmental, 2, a),)}
# 84          haïr   inf   {(segmental, 1, ʁ)}   {((segmental, 1, ʁ),)}
# 91        lisser   2sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 93        lisser   3sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 95        lisser   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 98        lisser  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
# 102       manger   2sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 104       manger   3sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 106       manger   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 109       manger  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
# 131       mourir  ptcp  {(segmental, 5, ɑ̃)}  {((segmental, 5, ɑ̃),)}
# 133       partir   1sg   {(segmental, 4, E)}   {((segmental, 4, E),)}
# 135       partir   2sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 137       partir   3sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 142       partir  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
# 161        peler   inf   {(segmental, 3, E)}   {((segmental, 3, E),)}
# 164        peler  ptcp  {(segmental, 6, ɑ̃)}  {((segmental, 6, ɑ̃),)}
# 175      pouvoir  ptcp  {(segmental, 6, ɑ̃)}  {((segmental, 6, ɑ̃),)}
# 186     recevoir  ptcp  {(segmental, 6, ɑ̃)}  {((segmental, 6, ɑ̃),)}
# 194  reconvoquer   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 197  reconvoquer  ptcp  {(segmental, 3, ɑ̃)}  {((segmental, 3, ɑ̃),)}
# 205    sonoriser   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 208    sonoriser  ptcp  {(segmental, 3, ɑ̃)}  {((segmental, 3, ɑ̃),)}
# 210       sortir   1sg   {(segmental, 4, E)}   {((segmental, 4, E),)}
# 212       sortir   2sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 214       sortir   3sg   {(segmental, 4, a)}   {((segmental, 4, a),)}
# 219       sortir  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
# 223     squeezer   2sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 225     squeezer   3sg   {(segmental, 3, a)}   {((segmental, 3, a),)}
# 227     squeezer   inf   {(segmental, 1, E)}   {((segmental, 1, E),)}
# 230     squeezer  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
# 238        touer   inf   {(segmental, 3, E)}   {((segmental, 3, E),)}
# 241        touer  ptcp  {(segmental, 4, ɑ̃)}  {((segmental, 4, ɑ̃),)}
#
#      # formatives
# 7               1
# 10              1
# 34              1
# 36              1
# 38              1
# 45              1
# 47              1
# 49              1
# 51              1
# 56              1
# 58              1
# 60              1
# 62              1
# 67              1
# 69              1
# 71              1
# 73              1
# 78              1
# 80              1
# 82              1
# 84              1
# 91              1
# 93              1
# 95              1
# 98              1
# 102             1
# 104             1
# 106             1
# 109             1
# 131             1
# 133             1
# 135             1
# 137             1
# 142             1
# 161             1
# 164             1
# 175             1
# 186             1
# 194             1
# 197             1
# 205             1
# 208             1
# 210             1
# 212             1
# 214             1
# 219             1
# 223             1
# 225             1
# 227             1
# 230             1
# 238             1
# 241             1

# %% [markdown]
# ### Verbose exponence

# %% [markdown]
# For a given value, v and some word $\omega$:

# %% [markdown]
# $$| \{  a \in \mathrm{wordform}(\omega): \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1$ \\
# $$

# %%
sm.count_formatives(values_words)
values_words[values_words.lexeme == "lisser"]
# Out:
#      lexeme value          form      cell  \
# 247  lisser   1pl  l i s Ø ʁ ɔ̃   fut.1pl
# 248  lisser   fut  l i s Ø ʁ ɔ̃   fut.1pl
# 249  lisser   1sg   l i s Ø ʁ E   fut.1sg
# 250  lisser   fut   l i s Ø ʁ E   fut.1sg
# 251  lisser   2pl   l i s Ø ʁ E   fut.2pl
# 252  lisser   fut   l i s Ø ʁ E   fut.2pl
# 253  lisser   2sg   l i s Ø ʁ a   fut.2sg
# 254  lisser   fut   l i s Ø ʁ a   fut.2sg
# 255  lisser   3pl  l i s Ø ʁ ɔ̃   fut.3pl
# 256  lisser   fut  l i s Ø ʁ ɔ̃   fut.3pl
# 257  lisser   3sg   l i s Ø ʁ a   fut.3sg
# 258  lisser   fut   l i s Ø ʁ a   fut.3sg
# 259  lisser   inf       l i s E       inf
# 260  lisser   1pl      l i s ɔ̃   prs.1pl
# 261  lisser   prs      l i s ɔ̃   prs.1pl
# 262  lisser   2pl       l i s E   prs.2pl
# 263  lisser   prs       l i s E   prs.2pl
# 264  lisser  ptcp      l i s ɑ̃  prs.ptcp
# 265  lisser   1pl     l i s a m   pst.1pl
# 266  lisser   pst     l i s a m   pst.1pl
# 267  lisser   1sg       l i s E   pst.1sg
# 268  lisser   pst       l i s E   pst.1sg
# 269  lisser   2pl     l i s a t   pst.2pl
# 270  lisser   pst     l i s a t   pst.2pl
# 271  lisser   2sg       l i s a   pst.2sg
# 272  lisser   pst       l i s a   pst.2sg
# 273  lisser   3pl     l i s E ʁ   pst.3pl
# 274  lisser   pst     l i s E ʁ   pst.3pl
# 275  lisser   3sg       l i s a   pst.3sg
# 276  lisser   pst       l i s a   pst.3sg
#
#                                              formative  # formatives
# 247                              ((segmental, 4, ɔ̃),)             1
# 248  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 249                               ((segmental, 4, E),)             1
# 250  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 251                               ((segmental, 4, E),)             1
# 252  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 253                               ((segmental, 3, a),)             1
# 254  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 255                              ((segmental, 4, ɔ̃),)             1
# 256  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 257                               ((segmental, 3, a),)             1
# 258  ((segmental, 1, Ø), (segmental, 2, ʁ), (segmen...             3
# 259                               ((segmental, 1, E),)             1
# 260                              ((segmental, 4, ɔ̃),)             1
# 261                              ((segmental, 4, ɔ̃),)             1
# 262                               ((segmental, 1, E),)             1
# 263                               ((segmental, 1, E),)             1
# 264                              ((segmental, 4, ɑ̃),)             1
# 265             ((segmental, 3, a), (segmental, 4, m))             2
# 266             ((segmental, 3, a), (segmental, 4, m))             2
# 267                               ((segmental, 1, E),)             1
# 268                               ((segmental, 1, E),)             1
# 269             ((segmental, 3, a), (segmental, 4, t))             2
# 270             ((segmental, 3, a), (segmental, 4, t))             2
# 271                               ((segmental, 3, a),)             1
# 272                               ((segmental, 3, a),)             1
# 273             ((segmental, 1, E), (segmental, 2, ʁ))             2
# 274             ((segmental, 1, E), (segmental, 2, ʁ))             2
# 275                               ((segmental, 3, a),)             1
# 276                               ((segmental, 3, a),)             1

# %% [markdown]
# **Measurement:**
#
# - '# of formatives': number of formatives expressing that valuein a given word
#
# To be implemented / further processing of the above dataframe:
# - We could also do an average of formatives expressing a given value
# - Number of cells where it is expressed verbose

# %% [markdown]
# ### Allomorphy

# %% [markdown]
# There is more than one formative which expresses a given value and these don't co-occur.

# %% [markdown]
# For a given value, $v$, we see allomorphy if:
#
# $$
# \exists a, b : \forall \delta_a, \delta_b, \exists x \in \delta \ ( v \in x $ )\\
# \{\Sigma \in \mathrm{dist}(a)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(b)| v \in \Sigma\} $$
#
# - There are two sets of formatives which both have v in some $x$ in their exponent set
# - They occur in distinct words

# %% [markdown]
# $$
# | \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1 \\
# \exists a_i,a_j : \{\Sigma \in \mathrm{dist}(a_i)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(a_j)| v \in \Sigma\}
# $$

# %% [markdown]
# 1. The number of formatives which have $v$ in all their deltas is more than one
# 2. There exist at least two formative which do not only occur in the same set of cells which contain $v$

# %%
sm.classify_allomorphy(fr_df, values)
values
# Out:
#     lexeme value                                          formative  \
# 0    aller   1pl  {(segmental, 1, a), (segmental, 2, ɔ̃), (segme...
# 1    aller   1sg             {(segmental, 1, E), (segmental, 0, v)}
# 2    aller   2pl  {(segmental, 1, E), (segmental, 1, a), (segmen...
# 3    aller   2sg             {(segmental, 1, a), (segmental, 0, v)}
# 4    aller   3pl  {(segmental, 1, E), (segmental, 2, ʁ), (segmen...
# ..     ...   ...                                                ...
# 237  touer   fut  {(segmental, 4, ɔ̃), (segmental, 3, a), (segme...
# 238  touer   inf                                {(segmental, 3, E)}
# 239  touer   prs  {(segmental, 1, u), (segmental, 3, E), (segmen...
# 240  touer   pst  {(segmental, 4, ʁ), (segmental, 2, w), (segmen...
# 241  touer  ptcp                               {(segmental, 4, ɑ̃)}
#
#                                     formatives_by_word  # formatives  \
# 0    {((segmental, 2, ɔ̃),), ((segmental, 1, a), (s...             4
# 1    {((segmental, 1, E),), ((segmental, 0, v), (se...             2
# 2    {((segmental, 0, al), (segmental, 1, E)), ((se...             4
# 3    {((segmental, 0, v), (segmental, 1, a)), ((seg...             2
# 4    {((segmental, 0, v), (segmental, 2, ɔ̃)), ((se...             4
# ..                                                 ...           ...
# 237  {((segmental, 1, u), (segmental, 2, ʁ), (segme...             5
# 238                             {((segmental, 3, E),)}             1
# 239  {((segmental, 2, w), (segmental, 4, ɔ̃)), ((se...             4
# 240  {((segmental, 2, w), (segmental, 3, a), (segme...             6
# 241                            {((segmental, 4, ɑ̃),)}             1
#
#      # allomorph sets  # words  % allomorph to words
# 0                   3        3            100.000000
# 1                   2        3             66.666667
# 2                   3        3            100.000000
# 3                   2        3             66.666667
# 4                   3        3            100.000000
# ..                ...      ...                   ...
# 237                 3        6             50.000000
# 238                 1        1            100.000000
# 239                 3        7             42.857143
# 240                 5        6             83.333333
# 241                 1        1            100.000000
#
# [242 rows x 8 columns]
