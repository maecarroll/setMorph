# %% [markdown]
# # Measuring & Classifying Exponence

# %% [markdown]
# **NOTES**:
# 1. Definitions are still a little ad-hoc but the intuition all works
# 2. Measures still need need to implemented

# %% [markdown]
# A typology of exponence derived in set-theoretic terms making use of setmorph tools

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import setmorph as sm
import itertools

# %% [markdown]
# Data files:

# %%
zen_df = sm.read_paradigms("src/setmorph/testdata/sample-zen-out.csv")
ngkolmpu_df = sm.read_paradigms("src/setmorph/testdata/sample-ng-tense-out.csv")
nuer_df = sm.read_paradigms("src/setmorph/testdata/sample-nuer-out.csv")
arabic_df = sm.read_paradigms("src/setmorph/testdata/sample-ar-out.csv")
rus_df = sm.read_paradigms("src/setmorph/testdata/sample-rus-out.csv")
fr_df = sm.read_paradigms("src/setmorph/testdata/sample-fr-out.csv")
uniq_df = sm.read_paradigms("src/setmorph/testdata/unique_test.csv")

# %% [markdown]
# Todo: csv tables for features + function to read them. TODO: pruned to a lexeme ? compare a defective lexeme.

# %%
fr_features = {
            'Tense': {frozenset({'prs'}), frozenset({'fut'}), frozenset({'pst'})},
            'Mode': {frozenset({'ptcp'}), frozenset({'inf'})},
            'PersonNumber': {frozenset({'1sg'}), frozenset({'2sg'}), frozenset({'3sg'}),
                             frozenset({'1pl'}), frozenset({'2pl'}), frozenset({'3pl'})}
            }

# %% [markdown]
# ## Delta

# %% [markdown]
# Delta is some feature based description of the distribution of a formative, $a$. It is a complete statement describing the cells where $a$ occurs. The total set of deltas for a formative can be considered the maximal knowledge of a speaker about the meaning/distribution of that formative.

# %% [markdown]
# - let $a$ be some formative
# - let $x$ be some set of features
# - let $y$ be some cell in $\mathrm{dist}(a)$
# - let $z$ be some cell in $\mathrm{cell}(\lambda)$
#
# We can then define $\delta_a$ as
# - some set of feature-sets, $\{ x_1, x_2, ... x_n \}$, such that:
#
# $$
# \forall x \in \delta_a, \exists y, z \ (x \subseteq y, z) \\
# \forall y, \exists x  \in \delta_a \ (y \supseteq x ) \\
# \forall z \supseteq x, \exists y \supseteq x \ (z = y)
# $$
#
# Which means:
# 1. All sets of features in $\delta_a$ are subsets of at least a cell which is in the distribution of $a$.
# 2. All cells in the distribution of $a$ are represented by a subset $x$ in $\delta_a$
# 3. All cells that are supersets of an $x$ in $\delta_a$ are in the distribution of $a$

# %% [markdown]
# ## Simple exponence

# %% [markdown]
# a formatve, $a$, is said to be a *simple exponent* iff:
#
# $$
# \exists |\delta_a| = 1 \\
# |x \in \delta_a| = 1
# $$

# %%
fr_df
# Out:
#      lexeme      cell    form       tier  slot formative     celllist
# 0     aller   prs.1sg     v E  segmental     0         v   (1sg, prs)
# 1     aller   prs.1sg     v E  segmental     1         E   (1sg, prs)
# 2     aller   prs.2sg     v a  segmental     0         v   (prs, 2sg)
# 3     aller   prs.2sg     v a  segmental     1         a   (prs, 2sg)
# 4     aller   prs.3sg     v a  segmental     0         v   (3sg, prs)
# ...     ...       ...     ...        ...   ...       ...          ...
# 1320  touer       inf   t w E  segmental     2         w        (inf)
# 1321  touer       inf   t w E  segmental     3         E        (inf)
# 1322  touer  prs.ptcp  t w ɑ̃  segmental     0         t  (ptcp, prs)
# 1323  touer  prs.ptcp  t w ɑ̃  segmental     2         w  (ptcp, prs)
# 1324  touer  prs.ptcp  t w ɑ̃  segmental     4        ɑ̃  (ptcp, prs)
#
# [1325 rows x 7 columns]

# %% [markdown]
# We start by computing all exponents relations once and for all:

# %%
exponents = sm.find_exponents(fr_df, fr_features)
exponents
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(2pl, prs), (1pl, prs), (pst)}          10
# 1                                              {(fut)}           6
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (2pl, prs), (pst, 3pl), (inf), (1...           7
# 4               {(3sg), (pst, 1pl), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a
# 0    {(pst, 2pl), (pst, 2sg), (pst, 3sg), (2pl, prs...
# 1    {(fut, 2sg), (fut, 2pl), (fut, 3sg), (fut, 1pl...
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}
# 3    {(fut, 2pl), (2pl, prs), (1sg, pst), (pst, 3pl...
# 4    {(fut, 2sg), (pst, 2pl), (pst, 2sg), (3sg, prs...
# ..                                                 ...
# 240                                       {(pst, 1pl)}
# 241                                       {(pst, 2pl)}
# 242                                      {(ptcp, prs)}
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}
# 244                                       {(pst, 3pl)}
#
# [245 rows x 7 columns]

# %%
simple = sm.classify_simple(exponents)
simple
# Out:
#     lexeme       tier  slot formative  \
# 0    aller  segmental     0        al
# 1    aller  segmental     0        iʁ
# 2    aller  segmental     0         v
# 3    aller  segmental     1         E
# 4    aller  segmental     1         a
# ..     ...        ...   ...       ...
# 240  touer  segmental     4         m
# 241  touer  segmental     4         t
# 242  touer  segmental     4        ɑ̃
# 243  touer  segmental     4        ɔ̃
# 244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(2pl, prs), (1pl, prs), (pst)}          10
# 1                                              {(fut)}           6
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (2pl, prs), (pst, 3pl), (inf), (1...           7
# 4               {(3sg), (pst, 1pl), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a simple?
# 0    {(pst, 2pl), (pst, 2sg), (pst, 3sg), (2pl, prs...      no
# 1    {(fut, 2sg), (fut, 2pl), (fut, 3sg), (fut, 1pl...     yes
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}      no
# 3    {(fut, 2pl), (2pl, prs), (1sg, pst), (pst, 3pl...      no
# 4    {(fut, 2sg), (pst, 2pl), (pst, 2sg), (3sg, prs...      no
# ..                                                 ...     ...
# 240                                       {(pst, 1pl)}     yes
# 241                                       {(pst, 2pl)}     yes
# 242                                      {(ptcp, prs)}     yes
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}      no
# 244                                       {(pst, 3pl)}     yes
#
# [245 rows x 8 columns]

# %% [markdown]
# ### Syncretism

# %% [markdown]
# A formative $a$ is considered to be an example of syncretism iff:
#
# $\neg\exists \delta_a : |\delta_a| = 1$

# %% [markdown]
# There does not exist a description of 'a', $\delta_a$, which has a cardinality of 1, i.e. one set of features.

# %%
dfsyn = sm.classify_syn(exponents)
dfsyn
# Out:
#      index lexeme       tier  slot formative  \
# 0        0  aller  segmental     0        al
# 1        1  aller  segmental     0        iʁ
# 2        2  aller  segmental     0         v
# 3        3  aller  segmental     1         E
# 4        4  aller  segmental     1         a
# ..     ...    ...        ...   ...       ...
# 240    240  touer  segmental     4         m
# 241    241  touer  segmental     4         t
# 242    242  touer  segmental     4        ɑ̃
# 243    243  touer  segmental     4        ɔ̃
# 244    244  touer  segmental     4         ʁ
#
#                                              exponence  # of cells  \
# 0                      {(2pl, prs), (1pl, prs), (pst)}          10
# 1                                              {(fut)}           6
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}           4
# 3    {(fut, 2pl), (2pl, prs), (pst, 3pl), (inf), (1...           7
# 4               {(3sg), (pst, 1pl), (pst, 2pl), (2sg)}           8
# ..                                                 ...         ...
# 240                                       {(pst, 1pl)}           1
# 241                                       {(pst, 2pl)}           1
# 242                                           {(ptcp)}           1
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}           3
# 244                                       {(pst, 3pl)}           1
#
#                                                 dist_a  \
# 0    {(pst, 2pl), (pst, 2sg), (pst, 3sg), (2pl, prs...
# 1    {(fut, 2sg), (fut, 2pl), (fut, 3sg), (fut, 1pl...
# 2     {(1sg, prs), (3sg, prs), (prs, 2sg), (3pl, prs)}
# 3    {(fut, 2pl), (2pl, prs), (1sg, pst), (pst, 3pl...
# 4    {(fut, 2sg), (pst, 2pl), (pst, 2sg), (3sg, prs...
# ..                                                 ...
# 240                                       {(pst, 1pl)}
# 241                                       {(pst, 2pl)}
# 242                                      {(ptcp, prs)}
# 243               {(fut, 3pl), (1pl, prs), (fut, 1pl)}
# 244                                       {(pst, 3pl)}
#
#      # sets minimally required
# 0                            3
# 1                            1
# 2                            4
# 3                            5
# 4                            4
# ..                         ...
# 240                          1
# 241                          1
# 242                          1
# 243                          3
# 244                          1
#
# [245 rows x 9 columns]

# %% [markdown]
# **Measurement**
#
# - Number of cells
# - Number of 'sets' in minimal description
#
# To be implemented:
# - TODO: Ratio of values over length of a dimension, i.e. 2 cases out of 12 total (harder to do given current implementation.

# %% [markdown]
# ### Cumulative exponence

# %% [markdown]
# A formative $a$ is considered an example of cumulative exponence iff:
#
# $\neg\exists \delta_a : \forall x \in \delta_a, |x| = 1$

# %% [markdown]
# There does not exists a $\delta_a$ such that for all sets of features in $\delta_a$ they have a cardinality of 1.

# %%
max_dimensions = fr_df["celllist"].fillna("").apply(len).max()
cumulation = sm.classify_cumulation(exponents, max_dimensions)
cumulation
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'minimal description'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27544/2962449974.py in <module>
#       1 max_dimensions = fr_df["celllist"].fillna("").apply(len).max()
# ----> 2 cumulation = sm.classify_cumulation(exponents, max_dimensions)
#       3 cumulation
#       4
#
# ~/bin/setMorph/src/setmorph/classify.py in classify_cumulation(df, max_dims)
#      42 def classify_cumulation(df, max_dims):
#      43     df = df.copy(deep=True)
# ---> 44     return df.apply(lambda form: cumulation_measures(form, max_dims), axis=1)
#      45
#      46
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~/bin/setMorph/src/setmorph/classify.py in <lambda>(form)
#      42 def classify_cumulation(df, max_dims):
#      43     df = df.copy(deep=True)
# ---> 44     return df.apply(lambda form: cumulation_measures(form, max_dims), axis=1)
#      45
#      46
#
# ~/bin/setMorph/src/setmorph/setmorph.py in cumulation_measures(formative, max_dims)
#     135                 the maximum number of dimensions.
#     136     """
# --> 137     cells = formative["minimal description"]
#     138     c_vals = cumulative(cells)
#     139     c_cells = cumulative_cells(c_vals, formative.dist_a)
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'minimal description'

# %% [markdown]
# **Measurement**
#
# - Longest cumulation: how many feature values get cumulated at most
# - Longest cumulation / longest possible cumulation
# - % cells cumulative - percentage of cells in dist(a) which must be described using cumulation (based on minimal descrition currently)
# - % dimensions - length of longest cumulation / longest possible cumulation

# %% [markdown]
# ## Unique exponence

# %% [markdown]
# For a given value, v:
# There is only one formative for which its all its deltas must contain that value:
#
# $\exists!a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) $

# %% [markdown]
# alternatively:

# %% [markdown]
# $| \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | = 1$

# %% [markdown]
# There exists exactly one $a$ such that all the descriptions of $a$, there exists a set in that description that contains that value.

# %%
uniq = sm.classify_unique(exponents)
uniq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27312/267067390.py in <module>
# ----> 1 uniq = sm.classify_unique(exponents)
#       2 uniq
#
# NameError: name 'exponents' is not defined

# %% [markdown]
# ### Verbose exponence

# %% [markdown]
# For a given value, v and some word $\omega$:

# %% [markdown]
# $$| \{  a \in \mathrm{wordform}(\omega): \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1$ \\
# $$

# %%
ve = sm.classify_verbose(exponents)
ve[ve.lexeme == "lisser"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27312/4038118316.py in <module>
# ----> 1 ve = sm.classify_verbose(exponents)
#       2 ve[ve.lexeme == "lisser"]
#
# NameError: name 'exponents' is not defined

# %% [markdown]
# TODO: This is missing the word itself, can be added by merging with the original df.

# %% [markdown]
# **Measurement:**
#
# - '# of formatives': number of formatives expressing that valuein a given word
#
# To be implemented / further processing of the above dataframe:
# - We could also do an average of formatives expressing a given value
# - Number of cells where it is expressed verbose

# %% [markdown]
# ### Allomorphy

# %% [markdown]
# This one is most problematic - still needs tweaking how it fits into the typology, how to measure and define.

# %% [markdown]
# There is more than one formative which expresses a given value and these don't co-occur.

# %% [markdown]
# For a given value, $v$, we see allomorphy if:
#
# $$
# \exists a, b : \forall \delta_a, \delta_b, \exists x \in \delta \ ( v \in x $ )\\
# \{\Sigma \in \mathrm{dist}(a)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(b)| v \in \Sigma\} $$

# %% [markdown]
# Alternatively:

# %% [markdown]
# $$
# | \{  a : \forall \delta_a, \exists x \in \delta_a \ (v \in x) \} | > 1 \\
# \exists a_i,a_j : \{\Sigma \in \mathrm{dist}(a_i)| v \in \Sigma\} \neq \{\Sigma \in \mathrm{dist}(a_j)| v \in \Sigma\}
# $$

# %% [markdown]
# 1. The number of formatives which have $v$ in all their deltas is more than one
# 2. There exist at least two formative which do not only occur in the same set of cells which contain $v$

# %%
allo = sm.classify_allomorphy(ngkolmpu_df)
pd.DataFrame(allo)
# Out:
# /home/sacha/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py:303: FutureWarning: Dropping invalid columns in SeriesGroupBy.agg is deprecated. In a future version, a TypeError will be raised. Before calling .agg, select only columns which should be valid for the aggregating function.
#   results[key] = self.aggregate(func)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     803                 sdata = splitter.sorted_data
# --> 804                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     805
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#    1348         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1349         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1350
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/bin/setMorph/src/setmorph/classify.py in exponence_word(paradigm)
#      25         transforms = {"celllist": [lambda d: exponence(cells, set(d)), len, set]}
# ---> 26         return groups.agg(transforms)
#      27
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     434             # key used for column selection and output
# --> 435             results = {
#     436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in <dictcomp>(.0)
#     435             results = {
# --> 436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     437             }
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     248             func = maybe_mangle_lambdas(func)
# --> 249             ret = self._aggregate_multiple_funcs(func)
#     250             if relabeling:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     302             key = base.OutputKey(label=name, position=idx)
# --> 303             results[key] = self.aggregate(func)
#     304
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     261             if self.grouper.nkeys > 1:
# --> 262                 return self._python_agg_general(func, *args, **kwargs)
#     263
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1347         if not output:
# -> 1348             return self._python_apply_general(f, self._selected_obj)
#    1349
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     840             group_axes = group.axes
# --> 841             res = f(group)
#     842             if not _is_indexed_like(res, group_axes, axis):
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1317         func = com.is_builtin_func(func)
# -> 1318         f = lambda x: func(x, *args, **kwargs)
#    1319
#
# ~/bin/setMorph/src/setmorph/classify.py in <lambda>(d)
#      24         groups = paradigm.groupby(["tier", "slot", "formative"])
# ---> 25         transforms = {"celllist": [lambda d: exponence(cells, set(d)), len, set]}
#      26         return groups.agg(transforms)
#
# TypeError: exponence() missing 1 required positional argument: 'feature_structure'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27312/53160339.py in <module>
# ----> 1 allo = sm.classify_allomorphy(ngkolmpu_df)
#       2 pd.DataFrame(allo)
#
# ~/bin/setMorph/src/setmorph/classify.py in classify_allomorphy(df)
#     102
#     103         # gets a list of the maximal delta for each formative
# --> 104         deltatable = exponents(dflex)
#     105
#     106         # goes through and makes a list of all for the formatives
#
# ~/bin/setMorph/src/setmorph/classify.py in exponents(df)
#      26         return groups.agg(transforms)
#      27
# ---> 28     result = df.groupby("lexeme").apply(exponence_word)
#      29     result.columns = ["exponence", "# of cells", "dist_a"]
#      30     return result.reset_index()
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1284
#    1285                 with group_selection_context(self):
# -> 1286                     return self._python_apply_general(f, self._selected_obj)
#    1287
#    1288         return result
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     802             try:
#     803                 sdata = splitter.sorted_data
# --> 804                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     805
#     806             except IndexError:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#    1347         # must return keys::list, values::list, mutated::bool
#    1348         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1349         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1350
#    1351     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/bin/setMorph/src/setmorph/classify.py in exponence_word(paradigm)
#      24         groups = paradigm.groupby(["tier", "slot", "formative"])
#      25         transforms = {"celllist": [lambda d: exponence(cells, set(d)), len, set]}
# ---> 26         return groups.agg(transforms)
#      27
#      28     result = df.groupby("lexeme").apply(exponence_word)
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     977
#     978         op = GroupByApply(self, func, args, kwargs)
# --> 979         result = op.agg()
#     980         if not is_dict_like(func) and result is not None:
#     981             return result
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     159
#     160         if is_dict_like(arg):
# --> 161             return self.agg_dict_like()
#     162         elif is_list_like(arg):
#     163             # we require a list, but not a 'str'
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     433         else:
#     434             # key used for column selection and output
# --> 435             results = {
#     436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     437             }
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/apply.py in <dictcomp>(.0)
#     434             # key used for column selection and output
#     435             results = {
# --> 436                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     437             }
#     438
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     247             # but not the class list / tuple itself.
#     248             func = maybe_mangle_lambdas(func)
# --> 249             ret = self._aggregate_multiple_funcs(func)
#     250             if relabeling:
#     251                 # error: Incompatible types in assignment (expression has type
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     301
#     302             key = base.OutputKey(label=name, position=idx)
# --> 303             results[key] = self.aggregate(func)
#     304
#     305         if any(isinstance(x, DataFrame) for x in results.values()):
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     260
#     261             if self.grouper.nkeys > 1:
# --> 262                 return self._python_agg_general(func, *args, **kwargs)
#     263
#     264             try:
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#    1346
#    1347         if not output:
# -> 1348             return self._python_apply_general(f, self._selected_obj)
#    1349
#    1350         return self._wrap_aggregated_output(output)
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     839             # group might be modified
#     840             group_axes = group.axes
# --> 841             res = f(group)
#     842             if not _is_indexed_like(res, group_axes, axis):
#     843                 mutated = True
#
# ~/anaconda3/envs/segment/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1316     def _python_agg_general(self, func, *args, **kwargs):
#    1317         func = com.is_builtin_func(func)
# -> 1318         f = lambda x: func(x, *args, **kwargs)
#    1319
#    1320         # iterate through "columns" ex exclusions to populate output dict
#
# ~/bin/setMorph/src/setmorph/classify.py in <lambda>(d)
#      23         cells = set(paradigm.celllist)
#      24         groups = paradigm.groupby(["tier", "slot", "formative"])
# ---> 25         transforms = {"celllist": [lambda d: exponence(cells, set(d)), len, set]}
#      26         return groups.agg(transforms)
#      27
#
# TypeError: exponence() missing 1 required positional argument: 'feature_structure'

# %% [markdown]
# **Measurement**
#
# - '# of allomorphs'
# - '% of allowmorphs to cells containing v' - this can be greater than 100% under current implementation.

# %% [markdown]
# Examples:
#
#
# | (a) SG|  | (b) SG |   | (c) SG |   | (d) SG |
# |---|      |---|        |---|        |---|
# |x|        | x  |       | x  |       | x  |
# |y|        | xy |       | x  |       | x  |
# |z|        |  y |       | xy |       | yz |

# %% [markdown]
# The current implementation treats the analysis of 'allomorphy of singular' as:
#
# - (a): x, y, z
# - (b): x, y
# - (c): x, y
# - (d): x, yz
#
# Another implementation might consider the following:
#
# - (a): x, y, z
# - (b): x, xy, y
# - (c): x, xy
# - (d): x, yz

# %% [markdown]
# ## Higher-order exceptionality

# %% [markdown]
# See Carroll (2022)
